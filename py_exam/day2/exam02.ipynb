# %%
age = 20

if age >= 20:
    print("성인입니다.")
# if age < 20:
# if age <= 19:
else:
    print("미성년자입니다.")
# Out:
# 성인입니다.

# %%
# 문제 1: 보기에 써있는 수자와 맞는 문장을 출력해주세요
# 보기
num = 10

if num == 10:
    print("10입니다.")
if num == 20:
    print("20입니다.")
if num == 30:
    print("30입니다.")
# -> 모두 실행됨
# Out:
# 10입니다.

# %%
num = 40

if num == 10:
    print("10입니다.")
elif num == 20:
    print("20입니다.")
elif num == 30:
    print("30입니다.")
# -> 양립 불가능(하나만 True)), 출력 안나올 수 있음

# %%
num = 30

if num == 10:
    print("10입니다.")
elif num == 20:
    print("20입니다.")
else:
    print("그 외입니다.")

# %%
# 문제 : 나이에 따른 올바른 말이 나오도록 해주세요.

age = 22

if age >= 20:
    print("성인입니다.")
else:
    print("미성년입니다.")
# Out:
# 성인입니다.

# %%
# 문제 : 실행되는 출력문에는 `참` 그렇지 않으면 `거짓` 이라고 적어주세요.
# 조건 : `참1`, `참2`, `거짓1` 이런 순으로 적어주세요.

# 개념시작
if ( True ):
  print("참")
    
if ( False ):
  print("거짓")
# 개념끝

# 문제시작
a = 10

# `==` => 같다.
if ( a == 10 ):
  print("참1")

# `!=` => 같지 않다.
if ( a != 10 ):
  print("거짓1")

if ( a > 10 ):
  print("거짓2")

if ( a >= 10 ):
  print("참2")

b = 10

if ( a == b ):
  print("참3")

# c 에는 true or false 이 담긴다.
c = a != b # c = False

if ( c ):
  print("거짓3")

if ( c == False ):
  print("참4")

# `not` => 반전
if ( not c ):
  print("참5")

if ( not(not c) ):
  print("거짓4")

d = True

if ( c != d ):
  print("참6")

if ( 10 > 5 and -6 > -10 and 10 != 10 ):
  print("거짓5")

if ( 10 < 5 and -6 < -10 and 10 != 10 or 10 > 5 ):
  print("참7")
# 문제끝
# Out:
# 참
# 참1
# 참2
# 참3
# 참4
# 참5
# 참6
# 참7

# %%
# 문제 : 10대, 20대, 30대 중 나이에 맞는 변수를 출력해주세요.

age = 15 # 25로 바꿔서 실행해보세요. 15로도 바꿔서 실행해보세요.

if age < 20:
    print("10대")
elif age < 30:
    print("20대")
elif age < 40:
    print("30대")
'''
print("== 정답 v1 ==")
if age >= 10 and age <= 19:
  print("10대")
if age >= 20 and age <= 29:
  print("20대")
if age >= 30 and age <= 39:
  print("30대")

print("== 정답 v2 ==")
if age >= 10 and age <= 19:
  print("10대")
elif age >= 20 and age <= 29:
  print("20대")
elif age >= 30 and age <= 39:
  print("30대")

print("== 정답 v3 ==")
if age >= 10 and age <= 19:
  print("10대")
elif age >= 20 and age <= 29:
  print("20대")
else:
  print("30대")

print("== 정답 v4 ==")
if age >= 10:
  if age <= 19:
    print("10대")

if age >= 20:
  if age <= 29:
    print("20대")

if age >= 30:
  if age <= 39:
    print("30대")

print("== 정답 v5 ==")
if age <= 19:
  print("10대")
elif age <= 29:
  print("20대")
elif age <= 39:
  print("30대")

print("== 정답 v6(깔끔) ==")
if age <= 19:
  print("10대")
elif age <= 29:
  print("20대")
else:
  print("30대")

print("== 정답 v7 ==")
if age >= 30:
  print("30대")
elif age >= 20:
  print("20대")
elif age >= 10:
  print("10대")

print("== 정답 v7(깔끔) ==")
if age >= 30:
  print("30대")
elif age >= 20:
  print("20대")
else:
  print("10대")
'''
# Out:
# 10대

# %%
# 문제 : 할인 대상인지 아닌지 출력해주세요.
# 조건 : 나이가 19세 이하이거나 60세 이상이면 할인 대상입니다.
# 조건 : `and, or`없이 풀어야 합니다.
# 조건 : 2가지 이상의 방법으로 풀어야 합니다.

age = 67

print("== 정답 v1 ==")
if age <= 19:
    print("할인 대상입니다.")
elif age >= 60:
    print("할인 대상입니다.")
else:
    print("할인 대상이 아닙니다.")

print("== 정답 v2 ==")

if age > 19:
    if age < 60:
        print("할인 대상이 아닙니다.")
else:
    print("할인 대상입니다.")

'''print("== 정답 v1 ==")

if age <= 19:
  print("할인 대상입니다.")

if age >= 60:
  print("할인 대상입니다.")

if age > 19:
  if age < 60:
    print("할인 대상이 아닙니다.")

print("== 정답 v2 ==")

if age < 20:
  print("할인 대상입니다.")
elif age >= 60:
  print("할인 대상입니다.")
else:
  print("할인 대상이 아닙니다.")
'''
# Out:
# == 정답 v1 ==
# 할인 대상입니다.
# == 정답 v2 ==
