# %% [markdown]
# __idle 에서 만든 모듈 ex1.py__
#
# a = 10
# b= '안녕'
#
# def fun1():
#      "모듈에 있는  첫 번째 함수"
#
# def fun2():
#     return a
#
# def fun3():
#     return b
#
# def fun4():
#     return "모듈에 있는 마지막 함수"

# %%
import ex1

print(ex1.fun1())
print(ex1.fun2())
print(ex1.fun3())
print(ex1.fun4())
# Out:
# 모듈에 있는  첫 번째 함수
# 10
# 안녕
# 모듈에 있는 마지막 함수
