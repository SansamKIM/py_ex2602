# %%
# git, github

print('Hi')
print('Hi')
print('Hi')
print('Hi')
# Out:
# 금
# 금

# %% [markdown]
# ### git 설정 명령어 추가
# - git remote remove origin : 깃 저장소 삭제
# - git remote add origin https://~~ : 깃 저장소 연결
#
# ### git 명령어 순서
# - git add .
# - git commit -m "..."
# - git push
#
# **origin = github 주소 별명**
