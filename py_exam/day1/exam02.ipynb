# %%
# 변수
x = 10
y = 5
print(x+y)

# %%
print("10" + "안녕")

# %%
# format형 (=치환문)
x = 10
y = 5

print("x : {}".format(x))
print("y : {}".format(y))

# %%
x = 10
y = 5

print("x:", x)
print("y:", y)

# %%
# 문제 1
x = 5
y = 10

print("x: {}".format(x))
print("y: {}".format(y))

# %%
# 문제 2
x = 10
y = 5

temp = x
x = y
y = temp

print("x: {}".format(x))
print("y: {}".format(y))
