# %%
# 파이썬 기본 자료형
age = 30
height = 170.5
name = "홍길동"
is_exercise = True

print(type(age))
print(type(height))
print(type(name))
print(type(is_exercise))

# 파이썬 컬렉션 자료형
weights = [60, 65, 70, 75]
print(weights)
print(type(weights))
 
person = {
    "age" : 40,
    "weight" : 68,
    "height" : 172
}

person_info = (40, 172, 68)
blood_pressures = {120, 130, 140}
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
# [60, 65, 70, 75]
# <class 'list'>

# %%
# 문제 1
a = 10
b = 20
'''
a = str(10)
b = str(20)

print(a + b)
'''
print(str(a) + str(b))
# Out:
# 1020

# %%
# 문제 2
a = '3'
b = '6'
'''
a = int(a)
b = int(b)

print(a + b)
'''
print(int(a) + int(b))
# Out:
# 9

# %%
# 문제 3
a = '3.1'
b = '6.1'
'''
a = float(a)
b = float(b)

print(a + b)
'''

print(float(a) + float(b))
# Out:
# 9.2

# %%
# 문제 4
a = '3.1'
b = '6.1'

a = float(a)
b = float(b)

print(int(a+b))

print(int(float(a) + float(b)))
# Out:
# 9
# 9
